# %% [markdown]
# # SETUP: KONFIGURASI PROYEK

# %%
import pandas as pd
import ast  # Untuk mengubah string dictionary menjadi dictionary
import matplotlib.pyplot as plt
import seaborn as sns # Library untuk visualisasi yang lebih baik
from collections import Counter
import numpy as np
from sklearn.model_selection import train_test_split
from transformers import RobertaTokenizer

# --- KONFIGURASI PROYEK ---
NAMA_FILE = 'SEntFiN-v1.1.csv'
RANDOM_STATE = 42
MAX_LENGTH = 40

# %% [markdown]
# # TAHAP 1: EKSPLORASI DATA

# %%
try:
  df = pd.read_csv(NAMA_FILE)
  print(f"Berhasil memuat {NAMA_FILE} ({len(df)} baris).\n")

  # --- 1.0: Melihat Data Mentah ---
  print("--- 1.0: Data Teratas (Head) ---")
  print(df.head())
  print("\n")

  print("--- 1.0: Tipe Data Kolom (Info) ---")
  df.info()
  print("Parsing kolom 'Decisions' (string -> dictionary)...")
  print("\n")

  try:
      df['Decisions_dict'] = df['Decisions'].apply(ast.literal_eval)
  except Exception as e:
      print(f"Error: Gagal parsing kolom 'Decisions'. Error: {e}")
      exit()

  # --- 1.1: Analisis Distribusi Jumlah Entitas per Berita ---
  print("--- 1.1: Analisis Jumlah Entitas per Berita ---")
  df['num_entities'] = df['Decisions_dict'].apply(len)

  print(df['num_entities'].describe())

  plt.figure(figsize=(8, 5))
  sns.countplot(x=df['num_entities'])
  plt.title('Distribusi Jumlah Entitas per Judul Berita')
  plt.xlabel('Jumlah Entitas')
  plt.ylabel('Frekuensi (Jumlah Judul)')
  plt.show()

  print(f"KESIMPULAN:\n1. Rata-rata {df['num_entities'].mean():.2f} entitas per berita.")
  print(f"2. Maksimum {df['num_entities'].max()} entitas dalam 1 berita.")

  # --- 1.2: Analisis Distribusi Label Sentimen ---
  print("\n--- 1.2: Analisis Distribusi Label ---")
  all_labels = [label for decisions in df['Decisions_dict'] for label in decisions.values()]
  label_counts = Counter(all_labels)

  print(f"Total label setelah di-flatten: {len(all_labels)}")
  print(f"Distribusi:\n{label_counts}")

  # Cek class imbalance
  if label_counts['neutral'] > (label_counts['positive'] + label_counts['negative']):
      print("KESIMPULAN: Data 'imbalanced'. Kita perlu 'Weighted Loss' & 'Macro F1'.")

  df_labels = pd.DataFrame(label_counts.items(), columns=['Label', 'Jumlah'])
  plt.figure(figsize=(8, 5))
  sns.barplot(data=df_labels, x='Label', y='Jumlah')
  plt.title('Distribusi Label Sentimen (Keseluruhan)')
  plt.xlabel('Sentimen')
  plt.ylabel('Jumlah')
  plt.show()

  # --- 1.3: Analisis Entitas Teratas ---
  print("\n--- 1.3: Analisis Entitas Teratas ---")
  all_entities = [entity for decisions in df['Decisions_dict'] for entity in decisions.keys()]
  entity_counts = Counter(all_entities)
  print("Entitas paling sering muncul (Top 10):")
  print(entity_counts.most_common(10))

  df_entities = pd.DataFrame(entity_counts.most_common(10), columns=['Entitas', 'Jumlah'])
  plt.figure(figsize=(10, 6))
  sns.barplot(data=df_entities, y='Entitas', x='Jumlah', orient='h')
  plt.title('Top 10 Entitas yang Paling Sering Muncul')
  plt.xlabel('Jumlah Kemunculan')
  plt.ylabel('Entitas')
  plt.show()

  # --- 1.4: Analisis Panjang Teks (Mencari MAX_LENGTH) ---
  print("\n--- 1.4: Analisis Panjang Teks (Mencari MAX_LENGTH) ---")
  print("Memuat tokenizer RoBERTa untuk menghitung panjang token...")
  tokenizer = RobertaTokenizer.from_pretrained('roberta-base')

  unique_titles = df['Title'].unique()
  token_lengths = [len(tokenizer.encode(title)) for title in unique_titles]
  lengths_series = pd.Series(token_lengths)

  print("\nStatistik Panjang Token:")
  print(lengths_series.describe(percentiles=[0.95, 0.99]))

  plt.figure(figsize=(10, 6))
  plt.hist(lengths_series, bins=30, edgecolor='k')
  plt.title('Distribusi Panjang Judul Berita (dalam Token)')
  plt.xlabel('Jumlah Token')
  plt.ylabel('Frekuensi')

  # --- PENENTUAN MAX_LENGTH SECARA OTOMATIS ---
  max_actual = lengths_series.max()
  persentil_99 = int(lengths_series.quantile(0.99))

  print(f"\nPanjang token MAKSIMUM aktual di dataset: {max_actual}")
  print(f"Panjang token 99% data: {persentil_99}")

  # MAX_LENGTH: max aktual dan bulatkan ke kelipatan 8 terdekat
  if max_actual % 8 == 0:
    MAX_LENGTH = max_actual
  else:
    MAX_LENGTH = max_actual + (8 - max_actual % 8)

  plt.axvline(max_actual, color='red', linestyle='dashed', linewidth=2)
  plt.text(max_actual + 1, 50, f'Max Aktual: {max_actual}', color='red')
  plt.axvline(MAX_LENGTH, color='blue', linestyle='dashed', linewidth=2)
  plt.text(MAX_LENGTH + 1, 100, f'MAX_LENGTH Dipilih: {MAX_LENGTH}', color='blue')
  plt.show()

  print(f"KESIMPULAN: MAX_LENGTH ditetapkan ke {MAX_LENGTH}.")

except FileNotFoundError:
  print(f"ERROR: File '{NAMA_FILE}' tidak ditemukan.")
  exit()
# Out:
# Berhasil memuat SEntFiN-v1.1.csv (10753 baris).
#
# --- 1.0: Data Teratas (Head) ---
#    S No.                                              Title  \
# 0      1  SpiceJet to issue 6.4 crore warrants to promoters
# 1      2                  MMTC Q2 net loss at Rs 10.4 crore
# 2      3  Mid-cap funds can deliver more, stay put: Experts
# 3      4             Mid caps now turn into market darlings
# 4      5  Market seeing patience, if not conviction: Pra...
#
#                        Decisions  Words
# 0        {"SpiceJet": "neutral"}      8
# 1            {"MMTC": "neutral"}      8
# 2  {"Mid-cap funds": "positive"}      8
# 3       {"Mid caps": "positive"}      7
# 4          {"Market": "neutral"}      8
#
#
# --- 1.0: Tipe Data Kolom (Info) ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10753 entries, 0 to 10752
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   S No.      10753 non-null  int64
#  1   Title      10753 non-null  object
#  2   Decisions  10753 non-null  object
#  3   Words      10753 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 336.2+ KB
# Parsing kolom 'Decisions' (string -> dictionary)...
#
#
# --- 1.1: Analisis Jumlah Entitas per Berita ---
# count    10753.000000
# mean         1.339998
# std          0.645567
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          7.000000
# Name: num_entities, dtype: float64
# KESIMPULAN:
# 1. Rata-rata 1.34 entitas per berita.
# 2. Maksimum 7 entitas dalam 1 berita.
#
# --- 1.2: Analisis Distribusi Label ---
# Total label setelah di-flatten: 14409
# Distribusi:
# Counter({'neutral': 5515, 'positive': 5075, 'negative': 3819})
# --- 1.3: Analisis Entitas Teratas ---
# Entitas paling sering muncul (Top 10):
# [('Nifty', 421), ('Sebi', 320), ('Sensex', 281), ('Infosys', 131), ('Gold', 123), ('BSE', 106), ('Rupee', 92), ('RBI', 88), ('rupee', 84), ('gold', 83)]
# --- 1.4: Analisis Panjang Teks (Mencari MAX_LENGTH) ---
# Memuat tokenizer RoBERTa untuk menghitung panjang token...
#
# Statistik Panjang Token:
# count    10686.000000
# mean        16.593393
# std          4.215957
# min          7.000000
# 50%         16.000000
# 95%         24.000000
# 99%         28.000000
# max         39.000000
# dtype: float64
#
# Panjang token MAKSIMUM aktual di dataset: 39
# Panjang token 99% data: 28
# KESIMPULAN: MAX_LENGTH ditetapkan ke 40.

# %% [markdown]
# # TAHAP 2: DATA SPLITTING

# %%
print("Melakukan split data 80/20 berdasarkan 'Judul Unik' (Anti-Leakage)...")

unique_titles = df['Title'].unique()
train_titles, test_titles = train_test_split(
  unique_titles,
  test_size=0.2,
  random_state=RANDOM_STATE
)
train_df = df[df['Title'].isin(train_titles)]
test_df = df[df['Title'].isin(test_titles)]

print(f"Judul unik untuk latih: {len(train_titles)}")
print(f"Judul unik untuk uji: {len(test_titles)}")

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # TAHAP 3: FLATTENING

# %%
def flatten_dataset(dataframe):
    flattened_data = []
    for _, row in dataframe.iterrows():
        sentence = row['Title']
        decisions = row['Decisions_dict']
        for entity, label in decisions.items():
            flattened_data.append({
                'entity': entity,
                'sentence': sentence,
                'label': label
            })
    return pd.DataFrame(flattened_data)

train_flat = flatten_dataset(train_df)
test_flat = flatten_dataset(test_df)

print(f"Data latih (flat) dibuat: {len(train_flat)} baris")
print(f"Data uji (flat) dibuat: {len(test_flat)} baris")
print("\nContoh data latih yang sudah di-flatten:")
print(train_flat.head())

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # TAHAP 4: PREPROCESSING

# %%
# --- 4.1: Label Encoding ---
print("\n--- 4.1: Label Encoding ---")
label2id = {'negative': 0, 'neutral': 1, 'positive': 2}
id2label = {v: k for k, v in label2id.items()}

train_flat['label_id'] = train_flat['label'].map(label2id)
test_flat['label_id'] = test_flat['label'].map(label2id)

print("Label 'positive', 'negative', 'neutral' telah diubah menjadi 0, 1, 2.")
print(train_flat[['entity', 'label', 'label_id']].head())

# --- 4.2: Tokenisasi ABSA (Demonstrasi) ---
print("\n--- 4.2: Tokenisasi ABSA (Demonstrasi) ---")
print(f"Demonstrasi tokenisasi menggunakan MAX_LENGTH = {MAX_LENGTH} (ditemukan di Tahap 1)")

try:
    contoh = train_flat.iloc[0]
    contoh_entity = contoh['entity']
    contoh_sentence = contoh['sentence']

    print(f"\nContoh Entity:   {contoh_entity}")
    print(f"Contoh Sentence: {contoh_sentence}")

    encoded_input = tokenizer(
        contoh_entity,
        contoh_sentence,
        padding='max_length',
        truncation=True,
        max_length=MAX_LENGTH,  # <-- Menggunakan nilai yang ditemukan di TAHAP 1
        return_tensors='pt'
    )

    print("\nHasil Tokenisasi (Input untuk Model):")
    print(encoded_input['input_ids'])

    print("\nFormat Teks (untuk manusia):")
    print(tokenizer.decode(encoded_input['input_ids'][0]))

except IndexError:
    print("Error: DataFrame latih kosong, tidak bisa mengambil sampel.")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TAHAP 5: PEMODELAN DENGAN RoBERTa

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from transformers import RobertaModel, get_linear_schedule_with_warmup
from sklearn.metrics import classification_report, accuracy_score, f1_score
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# --- 5.1: Setup Device (GPU/CPU) ---
print("--- 5.1: Setup Device ---")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device yang digunakan: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory Available: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")

# --- 5.2: Hitung Class Weights untuk Weighted Loss ---
print("\n--- 5.2: Menghitung Class Weights ---")
from sklearn.utils.class_weight import compute_class_weight

# Hitung class weights dari training data
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1, 2]),
    y=train_flat['label_id'].values
)
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

print(f"Class weights (untuk mengatasi imbalance):")
print(f"  - Negative (0): {class_weights[0]:.4f}")
print(f"  - Neutral  (1): {class_weights[1]:.4f}")
print(f"  - Positive (2): {class_weights[2]:.4f}")

print("\nKESIMPULAN: Class weights akan membuat model lebih fokus pada kelas minoritas.")
# Out:
# --- 5.1: Setup Device ---
# Device yang digunakan: cuda
# GPU: NVIDIA GeForce RTX 3060
# Memory Available: 12.88 GB
#
# --- 5.2: Menghitung Class Weights ---
# Class weights (untuk mengatasi imbalance):
#   - Negative (0): 1.2590
#   - Neutral  (1): 0.8697
#   - Positive (2): 0.9471
#
# KESIMPULAN: Class weights akan membuat model lebih fokus pada kelas minoritas.

# %%
# --- 5.3: Definisi Model RoBERTa untuk ABSA ---
print("\n--- 5.3: Definisi Model RoBERTa untuk ABSA ---")

class RobertaForABSA(nn.Module):
    def __init__(self, num_labels=3, dropout_rate=0.3):  
        super(RobertaForABSA, self).__init__()
        # Load pre-trained RoBERTa
        self.roberta = RobertaModel.from_pretrained('roberta-base')
        self.dropout = nn.Dropout(dropout_rate)
        # Classification head
        self.classifier = nn.Linear(self.roberta.config.hidden_size, num_labels)
        
    def forward(self, input_ids, attention_mask):
        # Get RoBERTa outputs
        outputs = self.roberta(
            input_ids=input_ids,
            attention_mask=attention_mask
        )
        # Use [CLS] token representation (pooled output)
        pooled_output = outputs.pooler_output
        pooled_output = self.dropout(pooled_output)
        # Classification
        logits = self.classifier(pooled_output)
        return logits

print("Model RoBERTa untuk ABSA telah didefinisikan.")
print("Arsitektur:")
print("  1. RoBERTa Base (12 layers, 768 hidden size)")
print("  2. Dropout (0.3)")  
print("  3. Linear Classifier (768 -> 3 classes)")
# Out:
# --- 5.3: Definisi Model RoBERTa untuk ABSA ---
# Model RoBERTa untuk ABSA telah didefinisikan.
# Arsitektur:
#   1. RoBERTa Base (12 layers, 768 hidden size)
#   2. Dropout (0.3)
#   3. Linear Classifier (768 -> 3 classes)

# %%
# --- 5.4: Inisialisasi Model, Loss Function, dan Optimizer ---
print("\n--- 5.4: Inisialisasi Model & Optimizer ---")

# Inisialisasi model
model = RobertaForABSA(num_labels=3, dropout_rate=0.3)  
model = model.to(device)

# Hitung jumlah parameter
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")

# Loss function dengan class weights DAN label smoothing
criterion = nn.CrossEntropyLoss(
    weight=class_weights,
    label_smoothing=0.05 
)
print(f"\nLoss Function: CrossEntropyLoss dengan class weights & label_smoothing=0.05")

# Optimizer: AdamW dengan learning rate lebih kecil
learning_rate = 2e-5 
optimizer = AdamW(model.parameters(), lr=learning_rate, weight_decay=0.01) 
print(f"Optimizer: AdamW (lr={learning_rate}, weight_decay=0.01)")

print("\nKESIMPULAN: Model, loss function, dan optimizer siap untuk training!")
# Out:
# --- 5.4: Inisialisasi Model & Optimizer ---
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Total parameters: 124,647,939
# Trainable parameters: 124,647,939
#
# Loss Function: CrossEntropyLoss dengan class weights & label_smoothing=0.05
# Optimizer: AdamW (lr=2e-05, weight_decay=0.01)
#
# KESIMPULAN: Model, loss function, dan optimizer siap untuk training!

# %% [markdown]
# # TAHAP 6: FINE-TUNING

# %%
# --- 6.1: Membuat PyTorch Dataset ---
print("--- 6.1: Membuat PyTorch Dataset ---")

class ABSADataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length):
        self.data = dataframe.reset_index(drop=True)
        self.tokenizer = tokenizer
        self.max_length = max_length
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        entity = self.data.loc[idx, 'entity']
        sentence = self.data.loc[idx, 'sentence']
        label = self.data.loc[idx, 'label_id']
        
        # Tokenisasi
        encoding = self.tokenizer(
            entity,
            sentence,
            padding='max_length',
            truncation=True,
            max_length=self.max_length,
            return_tensors='pt'
        )
        
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'label': torch.tensor(label, dtype=torch.long)
        }

# Buat dataset
train_dataset = ABSADataset(train_flat, tokenizer, MAX_LENGTH)
test_dataset = ABSADataset(test_flat, tokenizer, MAX_LENGTH)

print(f"Training dataset: {len(train_dataset)} samples")
print(f"Test dataset: {len(test_dataset)} samples")
# Out:
# --- 6.1: Membuat PyTorch Dataset ---
# Training dataset: 11493 samples
# Test dataset: 2916 samples

# %%
# --- 6.2: Membuat DataLoader ---
print("\n--- 6.2: Membuat DataLoader ---")

BATCH_SIZE = 128

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0  # Set to 0 untuk menghindari multiprocessing issues
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0
)

print(f"Batch size: {BATCH_SIZE}")
print(f"Training batches: {len(train_loader)}")
print(f"Test batches: {len(test_loader)}")

# --- 6.3: Setup Learning Rate Scheduler ---
print("\n--- 6.3: Setup Learning Rate Scheduler ---")

NUM_EPOCHS = 15
total_steps = len(train_loader) * NUM_EPOCHS
warmup_steps = int(0.1 * total_steps)  # 10% warmup

scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=warmup_steps,
    num_training_steps=total_steps
)

print(f"Total training steps: {total_steps}")
print(f"Warmup steps: {warmup_steps}")
print(f"Epochs: {NUM_EPOCHS}")
print("\nScheduler: Linear warmup + linear decay")
# Out:
# --- 6.2: Membuat DataLoader ---
# Batch size: 128
# Training batches: 90
# Test batches: 23
#
# --- 6.3: Setup Learning Rate Scheduler ---
# Total training steps: 1350
# Warmup steps: 135
# Epochs: 15
#
# Scheduler: Linear warmup + linear decay

# %%
# --- 6.4: Fungsi Training dan Evaluation ---
print("\n--- 6.4: Definisi Fungsi Training & Evaluation ---")

def train_epoch(model, data_loader, criterion, optimizer, scheduler, device):
    """Training untuk 1 epoch"""
    model.train()
    total_loss = 0
    predictions = []
    true_labels = []
    
    progress_bar = tqdm(data_loader, desc='Training')
    
    for batch in progress_bar:
        # Move to device
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)
        
        # Forward pass
        optimizer.zero_grad()
        logits = model(input_ids, attention_mask)
        loss = criterion(logits, labels)
        
        # Backward pass
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        scheduler.step()
        
        # Track metrics
        total_loss += loss.item()
        preds = torch.argmax(logits, dim=1).cpu().numpy()
        predictions.extend(preds)
        true_labels.extend(labels.cpu().numpy())
        
        # Update progress bar
        progress_bar.set_postfix({'loss': loss.item()})
    
    avg_loss = total_loss / len(data_loader)
    accuracy = accuracy_score(true_labels, predictions)
    f1_macro = f1_score(true_labels, predictions, average='macro')
    
    return avg_loss, accuracy, f1_macro


def evaluate(model, data_loader, criterion, device):
    """Evaluasi model"""
    model.eval()
    total_loss = 0
    predictions = []
    true_labels = []
    
    with torch.no_grad():
        progress_bar = tqdm(data_loader, desc='Evaluating')
        
        for batch in progress_bar:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)
            
            logits = model(input_ids, attention_mask)
            loss = criterion(logits, labels)
            
            total_loss += loss.item()
            preds = torch.argmax(logits, dim=1).cpu().numpy()
            predictions.extend(preds)
            true_labels.extend(labels.cpu().numpy())
            
            progress_bar.set_postfix({'loss': loss.item()})
    
    avg_loss = total_loss / len(data_loader)
    accuracy = accuracy_score(true_labels, predictions)
    f1_macro = f1_score(true_labels, predictions, average='macro')
    
    return avg_loss, accuracy, f1_macro, predictions, true_labels

print("Fungsi training dan evaluation telah didefinisikan.")
# Out:
# --- 6.4: Definisi Fungsi Training & Evaluation ---
# Fungsi training dan evaluation telah didefinisikan.

# %%
# --- 6.5: Training Loop dengan Early Stopping ---
print("\n--- 6.5: Training Loop dengan Early Stopping ---")

# Early stopping parameters
PATIENCE = 5
best_val_f1 = 0  
patience_counter = 0
best_model_state = None

# Tracking metrics
history = {
    'train_loss': [],
    'train_acc': [],
    'train_f1': [],
    'val_loss': [],
    'val_acc': [],
    'val_f1': []
}

print(f"Memulai training untuk {NUM_EPOCHS} epochs...")
print(f"Early stopping patience: {PATIENCE} epochs")
print("=" * 80)

for epoch in range(NUM_EPOCHS):
    print(f"\n{'='*80}")
    print(f"EPOCH {epoch + 1}/{NUM_EPOCHS}")
    print(f"{'='*80}")
    
    # Training
    train_loss, train_acc, train_f1 = train_epoch(
        model, train_loader, criterion, optimizer, scheduler, device
    )
    
    # Validation
    val_loss, val_acc, val_f1, _, _ = evaluate(
        model, test_loader, criterion, device
    )
    
    # Save metrics
    history['train_loss'].append(train_loss)
    history['train_acc'].append(train_acc)
    history['train_f1'].append(train_f1)
    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)
    history['val_f1'].append(val_f1)
    
    # Print epoch results
    print(f"\n{'='*80}")
    print(f"HASIL EPOCH {epoch + 1}:")
    print(f"  Training   -> Loss: {train_loss:.4f} | Acc: {train_acc:.4f} | F1-Macro: {train_f1:.4f}")
    print(f"  Validation -> Loss: {val_loss:.4f} | Acc: {val_acc:.4f} | F1-Macro: {val_f1:.4f}")
    print(f"{'='*80}")
    
    # Early stopping check berdasarkan validation F1-Macro
    if val_f1 > best_val_f1:  
        best_val_f1 = val_f1  
        patience_counter = 0
        best_model_state = model.state_dict().copy()
        print(f"✓ New best Validation F1-Macro: {best_val_f1:.4f} - Model saved!")
    else:
        patience_counter += 1
        print(f"✗ No improvement. Patience: {patience_counter}/{PATIENCE}")
        
        if patience_counter >= PATIENCE:
            print(f"\n{'='*80}")
            print(f"Early stopping triggered! Best Validation F1-Macro: {best_val_f1:.4f}") 
            print(f"{'='*80}")
            break

# Load best model
if best_model_state is not None:
    model.load_state_dict(best_model_state)
    print(f"\n✓ Best model loaded (Validation F1-Macro: {best_val_f1:.4f}")
# Out:
# --- 6.5: Training Loop dengan Early Stopping ---
# Memulai training untuk 15 epochs...
# Early stopping patience: 5 epochs
# ================================================================================
#
# ================================================================================
# EPOCH 1/15
# ================================================================================
# Training:   3%|▎         | 3/90 [00:01<00:44,  1.94it/s, loss=1.11]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:   4%|▍         | 4/90 [00:02<00:44,  1.94it/s, loss=1.12]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  12%|█▏        | 11/90 [00:05<00:40,  1.95it/s, loss=1.1]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  13%|█▎        | 12/90 [00:06<00:40,  1.94it/s, loss=1.11]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  21%|██        | 19/90 [00:09<00:36,  1.94it/s, loss=1.11]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  29%|██▉       | 26/90 [00:13<00:32,  1.96it/s, loss=1.11]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  31%|███       | 28/90 [00:14<00:31,  1.95it/s, loss=1.11]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  33%|███▎      | 30/90 [00:15<00:30,  1.95it/s, loss=1.11]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  42%|████▏     | 38/90 [00:19<00:26,  1.94it/s, loss=1.1] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  43%|████▎     | 39/90 [00:20<00:26,  1.94it/s, loss=1.1]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  48%|████▊     | 43/90 [00:22<00:24,  1.94it/s, loss=1.11]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  66%|██████▌   | 59/90 [00:29<00:15,  2.06it/s, loss=1.06]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  69%|██████▉   | 62/90 [00:31<00:13,  2.06it/s, loss=1.06]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  72%|███████▏  | 65/90 [00:32<00:12,  2.06it/s, loss=1.01] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  74%|███████▍  | 67/90 [00:33<00:11,  2.05it/s, loss=0.973]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training: 100%|██████████| 90/90 [00:44<00:00,  2.00it/s, loss=0.755]
# Evaluating:  35%|███▍      | 8/23 [00:01<00:02,  6.19it/s, loss=0.643]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  74%|███████▍  | 17/23 [00:02<00:00,  6.16it/s, loss=0.676]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating: 100%|██████████| 23/23 [00:03<00:00,  6.21it/s, loss=0.616]
# ================================================================================
# HASIL EPOCH 1:
#   Training   -> Loss: 1.0074 | Acc: 0.4510 | F1-Macro: 0.4483
#   Validation -> Loss: 0.5872 | Acc: 0.7984 | F1-Macro: 0.8000
# ================================================================================
# ✓ New best Validation F1-Macro: 0.8000 - Model saved!
#
# ================================================================================
# EPOCH 2/15
# ================================================================================
# Training:   1%|          | 1/90 [00:00<00:43,  2.06it/s, loss=0.729]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:   4%|▍         | 4/90 [00:01<00:41,  2.07it/s, loss=0.616]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:   8%|▊         | 7/90 [00:03<00:40,  2.07it/s, loss=0.59] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  16%|█▌        | 14/90 [00:06<00:39,  1.94it/s, loss=0.474]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  28%|██▊       | 25/90 [00:12<00:33,  1.93it/s, loss=0.539]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  39%|███▉      | 35/90 [00:17<00:27,  1.99it/s, loss=0.447]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  41%|████      | 37/90 [00:18<00:26,  2.04it/s, loss=0.397]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  44%|████▍     | 40/90 [00:20<00:24,  2.06it/s, loss=0.497]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  50%|█████     | 45/90 [00:22<00:21,  2.07it/s, loss=0.417]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  58%|█████▊    | 52/90 [00:25<00:18,  2.08it/s, loss=0.456]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  61%|██████    | 55/90 [00:27<00:16,  2.08it/s, loss=0.492]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  62%|██████▏   | 56/90 [00:27<00:16,  2.07it/s, loss=0.323]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  70%|███████   | 63/90 [00:31<00:13,  2.07it/s, loss=0.365]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  77%|███████▋  | 69/90 [00:34<00:10,  2.07it/s, loss=0.411]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  78%|███████▊  | 70/90 [00:34<00:09,  2.07it/s, loss=0.405]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  96%|█████████▌| 86/90 [00:42<00:01,  2.07it/s, loss=0.518]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training: 100%|██████████| 90/90 [00:44<00:00,  2.03it/s, loss=0.487]
# Evaluating:  35%|███▍      | 8/23 [00:01<00:02,  6.22it/s, loss=0.374]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  74%|███████▍  | 17/23 [00:02<00:00,  6.24it/s, loss=0.432]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating: 100%|██████████| 23/23 [00:03<00:00,  6.28it/s, loss=0.426]
# ================================================================================
# HASIL EPOCH 2:
#   Training   -> Loss: 0.4861 | Acc: 0.8521 | F1-Macro: 0.8527
#   Validation -> Loss: 0.4283 | Acc: 0.8865 | F1-Macro: 0.8879
# ================================================================================
# ✓ New best Validation F1-Macro: 0.8879 - Model saved!
#
# ================================================================================
# EPOCH 3/15
# ================================================================================
# Training:  14%|█▍        | 13/90 [00:06<00:37,  2.07it/s, loss=0.364]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  21%|██        | 19/90 [00:09<00:34,  2.07it/s, loss=0.379]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  22%|██▏       | 20/90 [00:09<00:33,  2.07it/s, loss=0.405]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  27%|██▋       | 24/90 [00:11<00:31,  2.07it/s, loss=0.323]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  29%|██▉       | 26/90 [00:12<00:30,  2.07it/s, loss=0.274]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  49%|████▉     | 44/90 [00:21<00:22,  2.07it/s, loss=0.375]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  53%|█████▎    | 48/90 [00:23<00:20,  2.07it/s, loss=0.402]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  56%|█████▌    | 50/90 [00:24<00:19,  2.07it/s, loss=0.402]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  57%|█████▋    | 51/90 [00:24<00:18,  2.07it/s, loss=0.407]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  62%|██████▏   | 56/90 [00:27<00:16,  2.08it/s, loss=0.435]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  66%|██████▌   | 59/90 [00:28<00:14,  2.07it/s, loss=0.409]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  72%|███████▏  | 65/90 [00:31<00:12,  2.07it/s, loss=0.356]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  73%|███████▎  | 66/90 [00:31<00:11,  2.06it/s, loss=0.372]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  78%|███████▊  | 70/90 [00:33<00:10,  1.95it/s, loss=0.351]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  98%|█████████▊| 88/90 [00:43<00:01,  1.92it/s, loss=0.39] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  99%|█████████▉| 89/90 [00:43<00:00,  1.91it/s, loss=0.48]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training: 100%|██████████| 90/90 [00:44<00:00,  2.03it/s, loss=0.442]
# Evaluating:  35%|███▍      | 8/23 [00:01<00:02,  5.80it/s, loss=0.377]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  74%|███████▍  | 17/23 [00:02<00:01,  5.80it/s, loss=0.38] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating: 100%|██████████| 23/23 [00:03<00:00,  5.88it/s, loss=0.388]
# ================================================================================
# HASIL EPOCH 3:
#   Training   -> Loss: 0.3782 | Acc: 0.9062 | F1-Macro: 0.9066
#   Validation -> Loss: 0.4375 | Acc: 0.8848 | F1-Macro: 0.8858
# ================================================================================
# ✗ No improvement. Patience: 1/5
#
# ================================================================================
# EPOCH 4/15
# ================================================================================
# Training:   0%|          | 0/90 [00:00<?, ?it/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:   3%|▎         | 3/90 [00:01<00:42,  2.06it/s, loss=0.345]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:   7%|▋         | 6/90 [00:02<00:40,  2.06it/s, loss=0.321]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  10%|█         | 9/90 [00:04<00:39,  2.07it/s, loss=0.345]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  27%|██▋       | 24/90 [00:11<00:32,  2.06it/s, loss=0.332]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  28%|██▊       | 25/90 [00:12<00:32,  2.02it/s, loss=0.33] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  34%|███▍      | 31/90 [00:15<00:30,  1.94it/s, loss=0.364]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  41%|████      | 37/90 [00:18<00:27,  1.92it/s, loss=0.279]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  46%|████▌     | 41/90 [00:20<00:25,  1.89it/s, loss=0.434]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  56%|█████▌    | 50/90 [00:25<00:21,  1.90it/s, loss=0.291]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  66%|██████▌   | 59/90 [00:29<00:16,  1.93it/s, loss=0.331]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  68%|██████▊   | 61/90 [00:30<00:15,  1.93it/s, loss=0.259]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  69%|██████▉   | 62/90 [00:31<00:14,  1.94it/s, loss=0.386]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  76%|███████▌  | 68/90 [00:34<00:11,  1.95it/s, loss=0.391]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  91%|█████████ | 82/90 [00:41<00:03,  2.01it/s, loss=0.301]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  99%|█████████▉| 89/90 [00:44<00:00,  2.03it/s, loss=0.314]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training: 100%|██████████| 90/90 [00:45<00:00,  1.99it/s, loss=0.374]
# Evaluating:  35%|███▍      | 8/23 [00:01<00:02,  5.97it/s, loss=0.345]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  74%|███████▍  | 17/23 [00:02<00:00,  6.02it/s, loss=0.423]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating: 100%|██████████| 23/23 [00:03<00:00,  6.04it/s, loss=0.435]
# ================================================================================
# HASIL EPOCH 4:
#   Training   -> Loss: 0.3280 | Acc: 0.9303 | F1-Macro: 0.9307
#   Validation -> Loss: 0.4196 | Acc: 0.8937 | F1-Macro: 0.8947
# ================================================================================
# ✓ New best Validation F1-Macro: 0.8947 - Model saved!
#
# ================================================================================
# EPOCH 5/15
# ================================================================================
# Training:   3%|▎         | 3/90 [00:01<00:43,  2.02it/s, loss=0.299]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  14%|█▍        | 13/90 [00:06<00:37,  2.03it/s, loss=0.358]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  18%|█▊        | 16/90 [00:07<00:36,  2.03it/s, loss=0.276]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  26%|██▌       | 23/90 [00:11<00:32,  2.04it/s, loss=0.308]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  29%|██▉       | 26/90 [00:12<00:31,  2.02it/s, loss=0.284]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  31%|███       | 28/90 [00:13<00:30,  2.02it/s, loss=0.279]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  34%|███▍      | 31/90 [00:15<00:29,  2.01it/s, loss=0.332]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  36%|███▌      | 32/90 [00:15<00:28,  2.01it/s, loss=0.272]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  40%|████      | 36/90 [00:17<00:27,  1.97it/s, loss=0.235]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  43%|████▎     | 39/90 [00:19<00:26,  1.94it/s, loss=0.392]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  61%|██████    | 55/90 [00:27<00:18,  1.92it/s, loss=0.238]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  68%|██████▊   | 61/90 [00:30<00:15,  1.91it/s, loss=0.283]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  73%|███████▎  | 66/90 [00:33<00:12,  1.96it/s, loss=0.252]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  76%|███████▌  | 68/90 [00:34<00:10,  2.01it/s, loss=0.251]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  81%|████████  | 73/90 [00:36<00:08,  2.06it/s, loss=0.26] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  93%|█████████▎| 84/90 [00:42<00:02,  2.07it/s, loss=0.23] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training: 100%|██████████| 90/90 [00:44<00:00,  2.00it/s, loss=0.323]
# Evaluating:  35%|███▍      | 8/23 [00:01<00:02,  6.14it/s, loss=0.37] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  74%|███████▍  | 17/23 [00:02<00:00,  6.18it/s, loss=0.456]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating: 100%|██████████| 23/23 [00:03<00:00,  6.21it/s, loss=0.446]
# ================================================================================
# HASIL EPOCH 5:
#   Training   -> Loss: 0.2961 | Acc: 0.9471 | F1-Macro: 0.9471
#   Validation -> Loss: 0.4442 | Acc: 0.8927 | F1-Macro: 0.8934
# ================================================================================
# ✗ No improvement. Patience: 1/5
#
# ================================================================================
# EPOCH 6/15
# ================================================================================
# Training:  11%|█         | 10/90 [00:04<00:38,  2.07it/s, loss=0.256]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  16%|█▌        | 14/90 [00:06<00:36,  2.07it/s, loss=0.264]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  21%|██        | 19/90 [00:09<00:34,  2.07it/s, loss=0.313]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  24%|██▍       | 22/90 [00:10<00:32,  2.07it/s, loss=0.273]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  31%|███       | 28/90 [00:13<00:30,  2.06it/s, loss=0.296]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  33%|███▎      | 30/90 [00:14<00:29,  2.06it/s, loss=0.299]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  34%|███▍      | 31/90 [00:15<00:28,  2.06it/s, loss=0.24] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  37%|███▋      | 33/90 [00:16<00:28,  2.00it/s, loss=0.26] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  39%|███▉      | 35/90 [00:17<00:28,  1.95it/s, loss=0.293]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  50%|█████     | 45/90 [00:22<00:23,  1.92it/s, loss=0.215]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  58%|█████▊    | 52/90 [00:25<00:19,  1.91it/s, loss=0.251]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  60%|██████    | 54/90 [00:27<00:18,  1.92it/s, loss=0.349]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  73%|███████▎  | 66/90 [00:32<00:11,  2.06it/s, loss=0.253]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  94%|█████████▍| 85/90 [00:42<00:02,  2.06it/s, loss=0.242]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  99%|█████████▉| 89/90 [00:43<00:00,  2.06it/s, loss=0.241]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training: 100%|██████████| 90/90 [00:44<00:00,  2.03it/s, loss=0.213]
# Evaluating:  35%|███▍      | 8/23 [00:01<00:02,  6.19it/s, loss=0.324]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  74%|███████▍  | 17/23 [00:02<00:00,  6.18it/s, loss=0.452]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating: 100%|██████████| 23/23 [00:03<00:00,  6.23it/s, loss=0.492]
# ================================================================================
# HASIL EPOCH 6:
#   Training   -> Loss: 0.2736 | Acc: 0.9564 | F1-Macro: 0.9566
#   Validation -> Loss: 0.4135 | Acc: 0.9064 | F1-Macro: 0.9074
# ================================================================================
# ✓ New best Validation F1-Macro: 0.9074 - Model saved!
#
# ================================================================================
# EPOCH 7/15
# ================================================================================
# Training:  27%|██▋       | 24/90 [00:12<00:34,  1.91it/s, loss=0.251]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  34%|███▍      | 31/90 [00:15<00:28,  2.05it/s, loss=0.247]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  39%|███▉      | 35/90 [00:17<00:26,  2.06it/s, loss=0.3]  Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  46%|████▌     | 41/90 [00:20<00:23,  2.07it/s, loss=0.266]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  49%|████▉     | 44/90 [00:22<00:22,  2.07it/s, loss=0.213]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  50%|█████     | 45/90 [00:22<00:21,  2.06it/s, loss=0.249]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  53%|█████▎    | 48/90 [00:24<00:20,  2.06it/s, loss=0.284]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  64%|██████▍   | 58/90 [00:29<00:15,  2.01it/s, loss=0.224]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  68%|██████▊   | 61/90 [00:30<00:14,  1.95it/s, loss=0.219]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  77%|███████▋  | 69/90 [00:34<00:10,  1.92it/s, loss=0.227]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  78%|███████▊  | 70/90 [00:35<00:10,  1.92it/s, loss=0.234]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  80%|████████  | 72/90 [00:36<00:09,  1.91it/s, loss=0.304]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  84%|████████▍ | 76/90 [00:38<00:07,  1.92it/s, loss=0.235]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  87%|████████▋ | 78/90 [00:39<00:06,  1.98it/s, loss=0.283]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  97%|█████████▋| 87/90 [00:43<00:01,  2.06it/s, loss=0.288]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training: 100%|██████████| 90/90 [00:45<00:00,  1.99it/s, loss=0.301]
# Evaluating:  35%|███▍      | 8/23 [00:01<00:02,  6.17it/s, loss=0.387]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  74%|███████▍  | 17/23 [00:02<00:00,  6.17it/s, loss=0.441]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating: 100%|██████████| 23/23 [00:03<00:00,  6.23it/s, loss=0.484]
# ================================================================================
# HASIL EPOCH 7:
#   Training   -> Loss: 0.2510 | Acc: 0.9685 | F1-Macro: 0.9686
#   Validation -> Loss: 0.4347 | Acc: 0.8981 | F1-Macro: 0.8987
# ...
# Training: 100%|██████████| 90/90 [00:44<00:00,  2.03it/s, loss=0.231]
# Evaluating:  35%|███▍      | 8/23 [00:01<00:02,  5.79it/s, loss=0.365]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  74%|███████▍  | 17/23 [00:02<00:01,  5.76it/s, loss=0.455]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating: 100%|██████████| 23/23 [00:03<00:00,  5.81it/s, loss=0.481]
# ================================================================================
# HASIL EPOCH 9:
#   Training   -> Loss: 0.2270 | Acc: 0.9776 | F1-Macro: 0.9776
#   Validation -> Loss: 0.4551 | Acc: 0.8988 | F1-Macro: 0.8999
# ================================================================================
# ✗ No improvement. Patience: 3/5
#
# ================================================================================
# EPOCH 10/15
# ================================================================================
# Training:   1%|          | 1/90 [00:00<00:47,  1.87it/s, loss=0.206]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:   3%|▎         | 3/90 [00:01<00:45,  1.90it/s, loss=0.232]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:   6%|▌         | 5/90 [00:02<00:44,  1.91it/s, loss=0.202]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:   7%|▋         | 6/90 [00:03<00:43,  1.91it/s, loss=0.22] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  16%|█▌        | 14/90 [00:07<00:38,  1.99it/s, loss=0.258]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  18%|█▊        | 16/90 [00:08<00:36,  2.03it/s, loss=0.255]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  27%|██▋       | 24/90 [00:12<00:31,  2.06it/s, loss=0.222]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  39%|███▉      | 35/90 [00:17<00:26,  2.06it/s, loss=0.251]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  61%|██████    | 55/90 [00:27<00:16,  2.07it/s, loss=0.229]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  76%|███████▌  | 68/90 [00:33<00:10,  2.06it/s, loss=0.194]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  79%|███████▉  | 71/90 [00:34<00:09,  2.06it/s, loss=0.208]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  81%|████████  | 73/90 [00:35<00:08,  2.06it/s, loss=0.187]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  82%|████████▏ | 74/90 [00:36<00:07,  2.06it/s, loss=0.254]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  86%|████████▌ | 77/90 [00:37<00:06,  2.06it/s, loss=0.193]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  89%|████████▉ | 80/90 [00:39<00:04,  2.06it/s, loss=0.188]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  94%|█████████▍| 85/90 [00:41<00:02,  2.06it/s, loss=0.186]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  98%|█████████▊| 88/90 [00:43<00:00,  2.07it/s, loss=0.179]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training: 100%|██████████| 90/90 [00:43<00:00,  2.05it/s, loss=0.246]
# Evaluating:  35%|███▍      | 8/23 [00:01<00:02,  6.13it/s, loss=0.377]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  74%|███████▍  | 17/23 [00:02<00:00,  6.15it/s, loss=0.451]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating: 100%|██████████| 23/23 [00:03<00:00,  6.19it/s, loss=0.454]
# ================================================================================
# HASIL EPOCH 10:
#   Training   -> Loss: 0.2191 | Acc: 0.9811 | F1-Macro: 0.9811
#   Validation -> Loss: 0.4631 | Acc: 0.8992 | F1-Macro: 0.9001
# ================================================================================
# ✗ No improvement. Patience: 4/5
#
# ================================================================================
# EPOCH 11/15
# ================================================================================
# Training:   2%|▏         | 2/90 [00:00<00:42,  2.05it/s, loss=0.179]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:   9%|▉         | 8/90 [00:03<00:39,  2.06it/s, loss=0.243]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  19%|█▉        | 17/90 [00:08<00:35,  2.07it/s, loss=0.21] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  21%|██        | 19/90 [00:09<00:34,  2.06it/s, loss=0.222]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  23%|██▎       | 21/90 [00:10<00:33,  2.06it/s, loss=0.187]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  31%|███       | 28/90 [00:13<00:30,  2.06it/s, loss=0.278]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  38%|███▊      | 34/90 [00:16<00:27,  2.06it/s, loss=0.229]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  42%|████▏     | 38/90 [00:18<00:25,  2.06it/s, loss=0.196]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  44%|████▍     | 40/90 [00:19<00:24,  2.06it/s, loss=0.265]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  47%|████▋     | 42/90 [00:20<00:23,  2.06it/s, loss=0.225]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  54%|█████▍    | 49/90 [00:23<00:19,  2.06it/s, loss=0.223]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  62%|██████▏   | 56/90 [00:27<00:17,  1.98it/s, loss=0.211]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  70%|███████   | 63/90 [00:30<00:14,  1.91it/s, loss=0.221]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  84%|████████▍ | 76/90 [00:37<00:07,  1.91it/s, loss=0.228]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  92%|█████████▏| 83/90 [00:41<00:03,  2.04it/s, loss=0.179]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training:  99%|█████████▉| 89/90 [00:44<00:00,  2.06it/s, loss=0.26] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Training: 100%|██████████| 90/90 [00:44<00:00,  2.02it/s, loss=0.243]
# Evaluating:  35%|███▍      | 8/23 [00:01<00:02,  6.15it/s, loss=0.382]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  74%|███████▍  | 17/23 [00:02<00:00,  6.13it/s, loss=0.445]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating: 100%|██████████| 23/23 [00:03<00:00,  6.17it/s, loss=0.47]
# ================================================================================
# HASIL EPOCH 11:
#   Training   -> Loss: 0.2139 | Acc: 0.9829 | F1-Macro: 0.9829
#   Validation -> Loss: 0.4667 | Acc: 0.9016 | F1-Macro: 0.9026
# ================================================================================
# ✗ No improvement. Patience: 5/5
#
# ================================================================================
# Early stopping triggered! Best Validation F1-Macro: 0.9074
# ================================================================================
#
# ✓ Best model loaded (Validation F1-Macro: 0.9074

# %%
# --- 6.6: Visualisasi Training History ---
print("\n--- 6.6: Visualisasi Training History ---")

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

epochs_range = range(1, len(history['train_loss']) + 1)

# Loss
axes[0].plot(epochs_range, history['train_loss'], 'b-o', label='Train Loss')
axes[0].plot(epochs_range, history['val_loss'], 'r-o', label='Validation Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training & Validation Loss')
axes[0].legend()
axes[0].grid(True)

# Accuracy
axes[1].plot(epochs_range, history['train_acc'], 'b-o', label='Train Accuracy')
axes[1].plot(epochs_range, history['val_acc'], 'r-o', label='Validation Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].set_title('Training & Validation Accuracy')
axes[1].legend()
axes[1].grid(True)

# F1-Macro
axes[2].plot(epochs_range, history['train_f1'], 'b-o', label='Train F1-Macro')
axes[2].plot(epochs_range, history['val_f1'], 'r-o', label='Validation F1-Macro')
axes[2].set_xlabel('Epoch')
axes[2].set_ylabel('F1-Macro')
axes[2].set_title('Training & Validation F1-Macro')
axes[2].legend()
axes[2].grid(True)

plt.tight_layout()
plt.show()

print("Visualisasi training history selesai.")
# Out:
# --- 6.6: Visualisasi Training History ---
# Visualisasi training history selesai.

# %%
# ==========================================================
# PENGUJIAN MODEL DENGAN DATA RANDOM
# ==========================================================

print("\n" + "="*80)
print("PENGUJIAN MODEL SENTIMEN")
print("="*80)

# --- Data Testing ---
test_headlines = [
    # Positive sentiment (5 sampel)
    {"title": "Reliance Industries posts record quarterly profit, shares surge 15%", 
     "entity": "Reliance Industries", "true_label": "positive"},
    
    {"title": "TCS announces massive hiring drive, plans to recruit 40,000 freshers", 
     "entity": "TCS", "true_label": "positive"},
    
    {"title": "Infosys wins major contract from European bank worth $1.5 billion", 
     "entity": "Infosys", "true_label": "positive"},
    
    {"title": "HDFC Bank reports strong Q4 results, beats analyst expectations", 
     "entity": "HDFC Bank", "true_label": "positive"},
    
    {"title": "Adani Ports traffic grows 12% YoY, expansion on track", 
     "entity": "Adani Ports", "true_label": "positive"},
    
    # Negative sentiment (5 sampel)
    {"title": "Vodafone Idea shares crash 20% after massive quarterly losses", 
     "entity": "Vodafone Idea", "true_label": "negative"},
    
    {"title": "Yes Bank faces regulatory action, stock plunges to 52-week low", 
     "entity": "Yes Bank", "true_label": "negative"},
    
    {"title": "Jet Airways suspends operations indefinitely, thousands of jobs at risk", 
     "entity": "Jet Airways", "true_label": "negative"},
    
    {"title": "DHFL defaults on payment, shares fall 35% in morning trade", 
     "entity": "DHFL", "true_label": "negative"},
    
    {"title": "Suzlon Energy reports huge losses, faces bankruptcy concerns", 
     "entity": "Suzlon Energy", "true_label": "negative"},
    
    # Neutral sentiment (5 sampel)
    {"title": "State Bank of India announces new savings account scheme", 
     "entity": "State Bank of India", "true_label": "neutral"},
    
    {"title": "Tata Motors to invest Rs 5000 crore in electric vehicle manufacturing", 
     "entity": "Tata Motors", "true_label": "neutral"},
    
    {"title": "Wipro appoints new CEO, announces strategic restructuring plan", 
     "entity": "Wipro", "true_label": "neutral"},
    
    {"title": "ICICI Bank launches digital lending platform for MSMEs", 
     "entity": "ICICI Bank", "true_label": "neutral"},
    
    {"title": "Asian Paints maintains market share amid intense competition", 
     "entity": "Asian Paints", "true_label": "neutral"}
]

print(f"\nTotal sampel untuk diuji: {len(test_headlines)}")
print("  • Positive: 5 sampel")
print("  • Negative: 5 sampel")
print("  • Neutral: 5 sampel")
print("\n" + "-"*80)


# --- Fungsi Prediksi ---
def predict_sentiment(model, tokenizer, entity, sentence, device, max_length):
    """Prediksi sentimen untuk satu berita"""
    model.eval()
    
    encoding = tokenizer(
        entity, sentence,
        padding='max_length',
        truncation=True,
        max_length=max_length,
        return_tensors='pt'
    )
    
    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)
    
    with torch.no_grad():
        logits = model(input_ids, attention_mask)
        probabilities = torch.softmax(logits, dim=1)
        predicted_class = torch.argmax(probabilities, dim=1).item()
        confidence = probabilities[0][predicted_class].item()
    
    return predicted_class, confidence


# --- Testing ---
print("\n" + "="*80)
print("HASIL PREDIKSI")
print("="*80 + "\n")

results = []

for i, item in enumerate(test_headlines, 1):
    entity = item['entity']
    title = item['title']
    true_label = item['true_label']
    
    # Prediksi
    pred_id, confidence = predict_sentiment(
        model, tokenizer, entity, title, device, MAX_LENGTH
    )
    
    pred_label = id2label[pred_id]
    is_correct = (pred_label == true_label)
    
    results.append({
        'entity': entity,
        'true_label': true_label,
        'pred_label': pred_label,
        'is_correct': is_correct,
        'confidence': confidence
    })
    
    # Print hasil
    status = '✅ BENAR' if is_correct else '❌ SALAH'
    print(f"[{i}/15] {entity}")
    print(f"     Prediksi: {pred_label.upper()} | Label Asli: {true_label.upper()} | {status}")
    print(f"     Confidence: {confidence*100:.2f}%\n")


# --- Ringkasan ---
results_df = pd.DataFrame(results)
accuracy = (results_df['is_correct'].sum() / len(results_df)) * 100

print("="*80)
print("RINGKASAN HASIL")
print("="*80)
print(f"\nAkurasi: {accuracy:.2f}% ({results_df['is_correct'].sum()}/15)")
print(f"Mean Confidence: {results_df['confidence'].mean()*100:.2f}%")

print("\nPrediksi per Kategori:")
for label in ['positive', 'negative', 'neutral']:
    subset = results_df[results_df['true_label'] == label]
    correct = subset['is_correct'].sum()
    total = len(subset)
    acc = (correct/total)*100 if total > 0 else 0
    print(f"  • {label.capitalize()}: {correct}/{total} benar ({acc:.1f}%)")

# Tampilkan kesalahan jika ada
errors = results_df[~results_df['is_correct']]
if len(errors) > 0:
    print(f"\nKesalahan Prediksi ({len(errors)} kasus):")
    for _, row in errors.iterrows():
        print(f"  • {row['entity']}: Prediksi {row['pred_label']} → Seharusnya {row['true_label']}")

print("\n" + "="*80)
print("PENGUJIAN SELESAI!")
print("="*80)
# Out:
# ================================================================================
# PENGUJIAN MODEL SENTIMEN
# ================================================================================
#
# Total sampel untuk diuji: 15
#   • Positive: 5 sampel
#   • Negative: 5 sampel
#   • Neutral: 5 sampel
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# HASIL PREDIKSI
# ================================================================================
#
# [1/15] Reliance Industries
#      Prediksi: POSITIVE | Label Asli: POSITIVE | ✅ BENAR
#      Confidence: 96.84%
#
# [2/15] TCS
#      Prediksi: NEUTRAL | Label Asli: POSITIVE | ❌ SALAH
#      Confidence: 90.58%
#
# [3/15] Infosys
#      Prediksi: POSITIVE | Label Asli: POSITIVE | ✅ BENAR
#      Confidence: 96.19%
#
# [4/15] HDFC Bank
#      Prediksi: POSITIVE | Label Asli: POSITIVE | ✅ BENAR
#      Confidence: 96.93%
#
# [5/15] Adani Ports
#      Prediksi: POSITIVE | Label Asli: POSITIVE | ✅ BENAR
#      Confidence: 97.35%
#
# [6/15] Vodafone Idea
#      Prediksi: NEGATIVE | Label Asli: NEGATIVE | ✅ BENAR
#      Confidence: 98.00%
#
# [7/15] Yes Bank
#      Prediksi: NEGATIVE | Label Asli: NEGATIVE | ✅ BENAR
#      Confidence: 98.27%
#
# [8/15] Jet Airways
#      Prediksi: NEGATIVE | Label Asli: NEGATIVE | ✅ BENAR
#      Confidence: 98.12%
#
# [9/15] DHFL
#      Prediksi: NEGATIVE | Label Asli: NEGATIVE | ✅ BENAR
#      Confidence: 98.19%
#
# [10/15] Suzlon Energy
#      Prediksi: NEGATIVE | Label Asli: NEGATIVE | ✅ BENAR
#      Confidence: 98.04%
#
# [11/15] State Bank of India
#      Prediksi: NEUTRAL | Label Asli: NEUTRAL | ✅ BENAR
#      Confidence: 96.43%
#
# [12/15] Tata Motors
#      Prediksi: NEUTRAL | Label Asli: NEUTRAL | ✅ BENAR
#      Confidence: 95.31%
#
# [13/15] Wipro
#      Prediksi: NEUTRAL | Label Asli: NEUTRAL | ✅ BENAR
#      Confidence: 96.16%
#
# [14/15] ICICI Bank
#      Prediksi: NEUTRAL | Label Asli: NEUTRAL | ✅ BENAR
#      Confidence: 96.46%
#
# [15/15] Asian Paints
#      Prediksi: POSITIVE | Label Asli: NEUTRAL | ❌ SALAH
#      Confidence: 90.92%
#
# ================================================================================
# RINGKASAN HASIL
# ================================================================================
#
# Akurasi: 86.67% (13/15)
# Mean Confidence: 96.25%
#
# Prediksi per Kategori:
#   • Positive: 4/5 benar (80.0%)
#   • Negative: 5/5 benar (100.0%)
#   • Neutral: 4/5 benar (80.0%)
#
# Kesalahan Prediksi (2 kasus):
#   • TCS: Prediksi neutral → Seharusnya positive
#   • Asian Paints: Prediksi positive → Seharusnya neutral
#
# ================================================================================
# PENGUJIAN SELESAI!
# ================================================================================

# %% [markdown]
# # MENYIMPAN MODEL

# %%
# ==========================================================
# TESTING MODEL YANG DI-LOAD DARI .PKL
# ==========================================================

print("="*80)
print("TESTING MODEL YANG DI-LOAD DARI .PKL")
print("="*80)

# Data testing (gunakan data yang sama seperti sebelumnya)
test_samples = [
    {"title": "Reliance Industries posts record quarterly profit, shares surge 15%", 
     "entity": "Reliance Industries", "true_label": "positive"},
    
    {"title": "Vodafone Idea shares crash 20% after massive quarterly losses", 
     "entity": "Vodafone Idea", "true_label": "negative"},
    
    {"title": "State Bank of India announces new savings account scheme", 
     "entity": "State Bank of India", "true_label": "neutral"},
]

print(f"\nTotal sampel untuk diuji: {len(test_samples)}\n")
print("-"*80 + "\n")

# Fungsi prediksi (reuse dari sebelumnya)
def predict_with_loaded_model(model, tokenizer, entity, sentence, device, max_length, id2label):
    """Prediksi sentimen menggunakan loaded model"""
    model.eval()
    
    encoding = tokenizer(
        entity, sentence,
        padding='max_length',
        truncation=True,
        max_length=max_length,
        return_tensors='pt'
    )
    
    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)
    
    with torch.no_grad():
        logits = model(input_ids, attention_mask)
        probabilities = torch.softmax(logits, dim=1)
        predicted_class = torch.argmax(probabilities, dim=1).item()
        confidence = probabilities[0][predicted_class].item()
    
    pred_label = id2label[predicted_class]
    return pred_label, confidence

# Testing
results = []
for i, item in enumerate(test_samples, 1):
    entity = item['entity']
    title = item['title']
    true_label = item['true_label']
    
    # Prediksi menggunakan loaded model
    pred_label, confidence = predict_with_loaded_model(
        loaded_model, loaded_tokenizer, entity, title, 
        device_loaded, loaded_max_length, loaded_id2label
    )
    
    is_correct = (pred_label == true_label)
    
    results.append({
        'entity': entity,
        'true_label': true_label,
        'pred_label': pred_label,
        'is_correct': is_correct,
        'confidence': confidence
    })
    
    # Print hasil
    status = '✅ BENAR' if is_correct else '❌ SALAH'
    print(f"[{i}/{len(test_samples)}] {entity}")
    print(f"     Headline: {title}")
    print(f"     Prediksi: {pred_label.upper()} | Label Asli: {true_label.upper()} | {status}")
    print(f"     Confidence: {confidence*100:.2f}%\n")

# Ringkasan
results_df = pd.DataFrame(results)
accuracy = (results_df['is_correct'].sum() / len(results_df)) * 100

print("="*80)
print("RINGKASAN")
print("="*80)
print(f"\n✓ Model dari .pkl berhasil digunakan untuk prediksi!")
print(f"  - Akurasi: {accuracy:.2f}% ({results_df['is_correct'].sum()}/{len(results_df)})")
print(f"  - Mean Confidence: {results_df['confidence'].mean()*100:.2f}%")
print("\n" + "="*80)
print("TESTING SELESAI!")
print("="*80)

# %% [markdown]
# # LOAD MODEL DARI .PKL FILE

# %%
import torch
import pickle
import io

print("="*80)
print("LOADING MODEL WITH CUSTOM CPU UNPICKLER")
print("="*80)

# Custom unpickler that forces everything to CPU
class CPUUnpickler(pickle.Unpickler):
    def find_class(self, module, name):
        if module == 'torch.storage' and name == '_load_from_bytes':
            return lambda b: torch.load(io.BytesIO(b), map_location='cpu')
        else:
            return super().find_class(module, name)

# Load model
model_file = 'roberta_absa_model.pkl'

try:
    print(f"\nLoading {model_file} with CPU unpickler...")
    with open(model_file, 'rb') as f:
        checkpoint = CPUUnpickler(f).load()
    print("✓ File loaded successfully!")
    print(f"  Type: {type(checkpoint)}")
    
    if isinstance(checkpoint, dict):
        print(f"  Keys: {list(checkpoint.keys())}")
    
except Exception as e:
    print(f"✗ Error: {e}")
    print("\n" + "="*80)
    print("ALTERNATIVE: Ask teammate to re-save model properly")
    print("="*80)
    raise

# Process checkpoint
print("\n" + "="*80)
print("BUILDING MODEL")
print("="*80)

from transformers import RobertaModel
import torch.nn as nn

class RobertaForABSA(nn.Module):
    def __init__(self, num_labels=3, dropout_rate=0.3):
        super(RobertaForABSA, self).__init__()
        self.roberta = RobertaModel.from_pretrained('roberta-base')
        self.dropout = nn.Dropout(dropout_rate)
        self.classifier = nn.Linear(self.roberta.config.hidden_size, num_labels)
        
    def forward(self, input_ids, attention_mask):
        outputs = self.roberta(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.pooler_output
        pooled_output = self.dropout(pooled_output)
        logits = self.classifier(pooled_output)
        return logits

# Create model
model = RobertaForABSA(num_labels=3, dropout_rate=0.3)

# Load state dict
if isinstance(checkpoint, dict):
    if 'model_state_dict' in checkpoint:
        state_dict = checkpoint['model_state_dict']
        
        # Force all tensors to CPU
        cpu_state_dict = {}
        for key, value in state_dict.items():
            if isinstance(value, torch.Tensor):
                cpu_state_dict[key] = value.cpu()
            else:
                cpu_state_dict[key] = value
        
        model.load_state_dict(cpu_state_dict)
        print("✓ Model state dict loaded")
        
        # Get metadata
        best_val_f1 = checkpoint.get('best_val_f1', 'N/A')
        epoch = checkpoint.get('epoch', 'N/A')
        label2id = checkpoint.get('label2id', {'negative': 0, 'neutral': 1, 'positive': 2})
        id2label = checkpoint.get('id2label', {0: 'negative', 1: 'neutral', 2: 'positive'})
        
        print(f"  Best Val F1: {best_val_f1}")
        print(f"  Epoch: {epoch}")
    else:
        # Direct state dict
        cpu_state_dict = {}
        for key, value in checkpoint.items():
            if isinstance(value, torch.Tensor):
                cpu_state_dict[key] = value.cpu()
            else:
                cpu_state_dict[key] = value
        model.load_state_dict(cpu_state_dict)
        label2id = {'negative': 0, 'neutral': 1, 'positive': 2}
        id2label = {0: 'negative', 1: 'neutral', 2: 'positive'}
else:
    # Whole model
    model = checkpoint.cpu()
    label2id = {'negative': 0, 'neutral': 1, 'positive': 2}
    id2label = {0: 'negative', 1: 'neutral', 2: 'positive'}

# Set to CPU and eval mode
device = torch.device('cpu')
model = model.to(device)
model.eval()

print("\n" + "="*80)
print("MODEL READY!")
print("="*80)
print(f"Device: {device}")
print(f"Labels: {id2label}")
print("\n✓ Model loaded successfully!")
# Out:
# ================================================================================
# LOADING MODEL WITH CUSTOM CPU UNPICKLER
# ================================================================================
#
# Loading roberta_absa_model.pkl with CPU unpickler...
# C:\Users\ACER NITRO V15\AppData\Local\Temp\ipykernel_14936\1604109819.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return lambda b: torch.load(io.BytesIO(b), map_location='cpu')
# ✓ File loaded successfully!
#   Type: <class 'dict'>
#   Keys: ['model_state_dict', 'model_class', 'tokenizer', 'label2id', 'id2label', 'max_length', 'best_val_f1', 'history', 'device']
#
# ================================================================================
# BUILDING MODEL
# ================================================================================
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✓ Model state dict loaded
#   Best Val F1: 0.9019348795744726
#   Epoch: N/A
#
# ================================================================================
# MODEL READY!
# ================================================================================
# Device: cpu
# Labels: {0: 'negative', 1: 'neutral', 2: 'positive'}
#
# ✓ Model loaded successfully!

# %% [markdown]
# # TAHAP 7: EVALUASI

# %% [markdown]
# Preprocessing

# %%
import pandas as pd
import ast
from sklearn.model_selection import train_test_split

print("="*80)
print("DATA PREPROCESSING & FLATTENING")
print("="*80)

# ===== 1. Load Dataset =====
print("\n1. Loading dataset...")
df = pd.read_csv('SEntFiN-v1.1.csv')
print(f"✓ Dataset loaded: {len(df)} rows")

# ===== 2. Parse Decisions Column =====
print("\n2. Parsing decisions column...")
df['Decisions'] = df['Decisions'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
print("✓ Decisions parsed")

# ===== 3. Split Dataset (80-20) BEFORE Flattening =====
print("\n3. Splitting dataset (80% train, 20% test)...")
RANDOM_STATE = 42

train_df, test_df = train_test_split(
    df, 
    test_size=0.2, 
    random_state=RANDOM_STATE,
    shuffle=True
)

print(f"✓ Train set: {len(train_df)} headlines")
print(f"✓ Test set: {len(test_df)} headlines")

# ===== 4. Flatten Function =====
def flatten_data(dataframe):
    """Flatten dataset: one row per entity"""
    flattened_rows = []
    
    for idx, row in dataframe.iterrows():
        title = row['Title']
        decisions = row['Decisions']
        
        # Each entity gets its own row
        for entity, sentiment in decisions.items():
            flattened_rows.append({
                'original_index': row['S No.'],
                'entity': entity,
                'sentence': title,
                'label': sentiment
            })
    
    return pd.DataFrame(flattened_rows)

# ===== 5. Flatten Train and Test =====
print("\n4. Flattening train and test sets...")

train_flattened = flatten_data(train_df)
test_flattened = flatten_data(test_df)

print(f"✓ Train flattened: {len(train_flattened)} samples")
print(f"✓ Test flattened: {len(test_flattened)} samples")

# ===== 6. Label Encoding =====
print("\n5. Encoding labels...")

label2id = {'negative': 0, 'neutral': 1, 'positive': 2}
id2label = {0: 'negative', 1: 'neutral', 2: 'positive'}

train_flattened['label_id'] = train_flattened['label'].map(label2id)
test_flattened['label_id'] = test_flattened['label'].map(label2id)

print("✓ Labels encoded")
print(f"  Mapping: {label2id}")

# ===== 7. Check Label Distribution =====
print("\n6. Label distribution in test set:")
print(test_flattened['label'].value_counts())
print(f"\nPercentage:")
print(test_flattened['label'].value_counts(normalize=True) * 100)

# ===== 8. Display Sample =====
print("\n7. Sample from test set:")
print(test_flattened.head())

print("\n" + "="*80)
print("DATA READY FOR EVALUATION!")
print("="*80)
print(f"\n✓ train_flattened: {len(train_flattened)} samples")
print(f"✓ test_flattened: {len(test_flattened)} samples")
print(f"✓ Variables ready: train_flattened, test_flattened, label2id, id2label")
# Out:
# ================================================================================
# DATA PREPROCESSING & FLATTENING
# ================================================================================
#
# 1. Loading dataset...
# ✓ Dataset loaded: 10753 rows
#
# 2. Parsing decisions column...
# ✓ Decisions parsed
#
# 3. Splitting dataset (80% train, 20% test)...
# ✓ Train set: 8602 headlines
# ✓ Test set: 2151 headlines
#
# 4. Flattening train and test sets...
# ✓ Train flattened: 11510 samples
# ✓ Test flattened: 2899 samples
#
# 5. Encoding labels...
# ✓ Labels encoded
#   Mapping: {'negative': 0, 'neutral': 1, 'positive': 2}
#
# 6. Label distribution in test set:
# label
# neutral     1084
# positive    1025
# negative     790
# Name: count, dtype: int64
#
# Percentage:
# label
# neutral     37.392204
# positive    35.357020
# negative    27.250776
# Name: proportion, dtype: float64
#
# 7. Sample from test set:
#    original_index           entity  \
# 0             669             Sebi
# 1            5334         Vodafone
# 2            5334  European shares
# 3            4437      M&M Finance
# 4            2329            Wipro
#
#                                             sentence     label  label_id
# 0  Ponzi schemes: Sebi seeks quarterly meetings o...   neutral         1
# 1    European shares steady, pegged back by Vodafone  negative         0
# 2    European shares steady, pegged back by Vodafone   neutral         1
# 3  M&M Finance plunges 8.5% as brokers cut target...  negative         0
# 4  Maintain 'Buy' on Wipro with target of Rs 528:...  positive         2
#
# ================================================================================
# DATA READY FOR EVALUATION!
# ================================================================================
#
# ✓ train_flattened: 11510 samples
# ✓ test_flattened: 2899 samples
# ✓ Variables ready: train_flattened, test_flattened, label2id, id2label

# %% [markdown]
# Prepare Test Data & Tokenizer

# %%
from transformers import RobertaTokenizer
from torch.utils.data import Dataset, DataLoader

print("="*80)
print("TAHAP 7: EVALUASI MODEL PADA TEST SET")
print("="*80)

# Load tokenizer
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
print("✓ Tokenizer loaded")

# Pastikan test_flattened sudah ada dari preprocessing sebelumnya
# Jika belum, jalankan cell preprocessing dulu

print(f"\nTest set size: {len(test_flattened)} samples")
print(f"Columns: {test_flattened.columns.tolist()}")

# Create Dataset
class ABSADataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length):
        self.data = dataframe.reset_index(drop=True)
        self.tokenizer = tokenizer
        self.max_length = max_length
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        entity = self.data.loc[idx, 'entity']
        sentence = self.data.loc[idx, 'sentence']
        label = self.data.loc[idx, 'label_id']
        
        encoding = self.tokenizer(
            entity,
            sentence,
            padding='max_length',
            truncation=True,
            max_length=self.max_length,
            return_tensors='pt'
        )
        
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'label': torch.tensor(label, dtype=torch.long)
        }

# Create test dataset and loader
MAX_LENGTH = 40  # Sesuai dengan yang dipakai saat training
test_dataset = ABSADataset(test_flattened, tokenizer, MAX_LENGTH)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print(f"\n✓ Test dataset created: {len(test_dataset)} samples")
print(f"✓ Test loader created: {len(test_loader)} batches")
# Out:
# ================================================================================
# TAHAP 7: EVALUASI MODEL PADA TEST SET
# ================================================================================
# ✓ Tokenizer loaded
#
# Test set size: 2899 samples
# Columns: ['original_index', 'entity', 'sentence', 'label', 'label_id']
#
# ✓ Test dataset created: 2899 samples
# ✓ Test loader created: 91 batches

# %% [markdown]
# Run Evaluation

# %%
import numpy as np
from tqdm import tqdm

print("\n" + "="*80)
print("RUNNING EVALUATION ON TEST SET")
print("="*80)

model.eval()
device = torch.device('cpu')

all_predictions = []
all_true_labels = []
all_confidences = []
all_entities = []
all_sentences = []

print("\nProcessing test set...")

with torch.no_grad():
    for batch_idx, batch in enumerate(tqdm(test_loader, desc="Evaluating")):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)
        
        # Forward pass
        logits = model(input_ids, attention_mask)
        probabilities = torch.softmax(logits, dim=1)
        predictions = torch.argmax(probabilities, dim=1)
        confidences = torch.max(probabilities, dim=1)[0]
        
        # Collect results
        all_predictions.extend(predictions.cpu().numpy())
        all_true_labels.extend(labels.cpu().numpy())
        all_confidences.extend(confidences.cpu().numpy())

# Convert to numpy arrays
all_predictions = np.array(all_predictions)
all_true_labels = np.array(all_true_labels)
all_confidences = np.array(all_confidences)

# Also get entities and sentences for error analysis
all_entities = test_flattened['entity'].values
all_sentences = test_flattened['sentence'].values

print(f"\n✓ Evaluation complete!")
print(f"  Total predictions: {len(all_predictions)}")
# Out:
# ================================================================================
# RUNNING EVALUATION ON TEST SET
# ================================================================================
#
# Processing test set...
# Evaluating:  15%|█▌        | 14/91 [00:10<00:55,  1.38it/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  30%|██▉       | 27/91 [00:21<00:57,  1.12it/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  43%|████▎     | 39/91 [00:32<00:48,  1.07it/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  45%|████▌     | 41/91 [00:34<00:46,  1.08it/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  81%|████████▏ | 74/91 [00:55<00:10,  1.65it/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating:  84%|████████▎ | 76/91 [00:57<00:08,  1.68it/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating: 100%|██████████| 91/91 [01:06<00:00,  1.37it/s]
# ✓ Evaluation complete!
#   Total predictions: 2899

# %% [markdown]
# Calculate Metrics

# %%
from sklearn.metrics import (
    accuracy_score, 
    f1_score, 
    precision_score,
    recall_score,
    classification_report,
    confusion_matrix
)

print("\n" + "="*80)
print("HASIL EVALUASI - TEST SET")
print("="*80)

# Overall metrics
test_accuracy = accuracy_score(all_true_labels, all_predictions)
test_f1_macro = f1_score(all_true_labels, all_predictions, average='macro')
test_f1_weighted = f1_score(all_true_labels, all_predictions, average='weighted')
test_precision_macro = precision_score(all_true_labels, all_predictions, average='macro')
test_recall_macro = recall_score(all_true_labels, all_predictions, average='macro')

print(f"\n📊 OVERALL PERFORMANCE:")
print(f"{'─'*60}")
print(f"  Accuracy          : {test_accuracy:.4f} ({test_accuracy*100:.2f}%)")
print(f"  F1-Score (Macro)  : {test_f1_macro:.4f}")
print(f"  F1-Score (Weighted): {test_f1_weighted:.4f}")
print(f"  Precision (Macro) : {test_precision_macro:.4f}")
print(f"  Recall (Macro)    : {test_recall_macro:.4f}")
print(f"  Mean Confidence   : {np.mean(all_confidences):.4f} ({np.mean(all_confidences)*100:.1f}%)")

# Per-class metrics
print(f"\n📈 PER-CLASS PERFORMANCE:")
print(f"{'─'*60}")

target_names = ['Negative', 'Neutral', 'Positive']
print(classification_report(
    all_true_labels, 
    all_predictions, 
    target_names=target_names,
    digits=4
))

# Compare with validation performance
print(f"\n📊 VALIDATION vs TEST COMPARISON:")
print(f"{'─'*60}")
print(f"  Validation F1 (from training): 0.9019 (90.19%)")
print(f"  Test F1 (current)            : {test_f1_macro:.4f} ({test_f1_macro*100:.2f}%)")
difference = test_f1_macro - 0.9019
if abs(difference) < 0.02:
    print(f"  Difference: {difference:+.4f} → ✓ Model generalizes well!")
elif difference < 0:
    print(f"  Difference: {difference:+.4f} → ⚠️ Slight performance drop on test set")
else:
    print(f"  Difference: {difference:+.4f} → ✓ Even better on test set!")
# Out:
# ================================================================================
# HASIL EVALUASI - TEST SET
# ================================================================================
#
# 📊 OVERALL PERFORMANCE:
# ────────────────────────────────────────────────────────────
#   Accuracy          : 0.9755 (97.55%)
#   F1-Score (Macro)  : 0.9757
#   F1-Score (Weighted): 0.9755
#   Precision (Macro) : 0.9753
#   Recall (Macro)    : 0.9761
#   Mean Confidence   : 0.9622 (96.2%)
#
# 📈 PER-CLASS PERFORMANCE:
# ────────────────────────────────────────────────────────────
#               precision    recall  f1-score   support
#
#     Negative     0.9736    0.9810    0.9773       790
#      Neutral     0.9794    0.9640    0.9716      1084
#     Positive     0.9730    0.9834    0.9782      1025
#
#     accuracy                         0.9755      2899
#    macro avg     0.9753    0.9761    0.9757      2899
# weighted avg     0.9755    0.9755    0.9755      2899
#
#
# 📊 VALIDATION vs TEST COMPARISON:
# ────────────────────────────────────────────────────────────
#   Validation F1 (from training): 0.9019 (90.19%)
#   Test F1 (current)            : 0.9757 (97.57%)
#   Difference: +0.0738 → ✓ Even better on test set!

# %% [markdown]
# Confusion Matrix Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("\n" + "="*80)
print("CONFUSION MATRIX")
print("="*80)

# Calculate confusion matrix
cm = confusion_matrix(all_true_labels, all_predictions)

# Create figure
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot 1: Count matrix
sns.heatmap(
    cm, 
    annot=True, 
    fmt='d', 
    cmap='Blues',
    xticklabels=target_names,
    yticklabels=target_names,
    cbar_kws={'label': 'Count'},
    ax=ax1,
    annot_kws={'size': 14, 'weight': 'bold'}
)
ax1.set_title('Confusion Matrix - Counts', fontsize=16, fontweight='bold', pad=20)
ax1.set_ylabel('True Label', fontsize=13, fontweight='bold')
ax1.set_xlabel('Predicted Label', fontsize=13, fontweight='bold')

# Plot 2: Normalized matrix (percentages)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
sns.heatmap(
    cm_normalized, 
    annot=True, 
    fmt='.2%', 
    cmap='YlOrRd',
    xticklabels=target_names,
    yticklabels=target_names,
    cbar_kws={'label': 'Percentage'},
    ax=ax2,
    annot_kws={'size': 14, 'weight': 'bold'}
)
ax2.set_title('Confusion Matrix - Normalized', fontsize=16, fontweight='bold', pad=20)
ax2.set_ylabel('True Label', fontsize=13, fontweight='bold')
ax2.set_xlabel('Predicted Label', fontsize=13, fontweight='bold')

plt.tight_layout()
plt.show()

# Print confusion matrix analysis
print("\n📊 CONFUSION MATRIX ANALYSIS:")
print(f"{'─'*60}")

for i, true_class in enumerate(target_names):
    total = cm[i].sum()
    correct = cm[i, i]
    accuracy_class = correct / total if total > 0 else 0
    
    print(f"\n{true_class.upper()}:")
    print(f"  Total samples: {total}")
    print(f"  Correct predictions: {correct} ({accuracy_class*100:.1f}%)")
    
    # Show misclassifications
    if total > correct:
        print(f"  Misclassifications:")
        for j, pred_class in enumerate(target_names):
            if i != j and cm[i, j] > 0:
                print(f"    → {pred_class}: {cm[i, j]} ({cm[i, j]/total*100:.1f}%)")
# Out:
# ================================================================================
# CONFUSION MATRIX
# ================================================================================
# 📊 CONFUSION MATRIX ANALYSIS:
# ────────────────────────────────────────────────────────────
#
# NEGATIVE:
#   Total samples: 790
#   Correct predictions: 775 (98.1%)
#   Misclassifications:
#     → Neutral: 12 (1.5%)
#     → Positive: 3 (0.4%)
#
# NEUTRAL:
#   Total samples: 1084
#   Correct predictions: 1045 (96.4%)
#   Misclassifications:
#     → Negative: 14 (1.3%)
#     → Positive: 25 (2.3%)
#
# POSITIVE:
#   Total samples: 1025
#   Correct predictions: 1008 (98.3%)
#   Misclassifications:
#     → Negative: 7 (0.7%)
#     → Neutral: 10 (1.0%)

# %% [markdown]
# # TAHAP 8: ANALISIS

# %% [markdown]
# Error Analysis

# %%
print("\n" + "="*80)
print("TAHAP 8: ERROR ANALYSIS")
print("="*80)

# Find misclassified examples
errors_mask = all_predictions != all_true_labels
num_errors = errors_mask.sum()
error_rate = num_errors / len(all_predictions)

print(f"\n📋 ERROR STATISTICS:")
print(f"{'─'*60}")
print(f"  Total errors: {num_errors} / {len(all_predictions)}")
print(f"  Error rate: {error_rate*100:.2f}%")
print(f"  Accuracy: {(1-error_rate)*100:.2f}%")

# Analyze errors by confidence
low_conf_errors = errors_mask & (all_confidences < 0.5)
med_conf_errors = errors_mask & (all_confidences >= 0.5) & (all_confidences < 0.8)
high_conf_errors = errors_mask & (all_confidences >= 0.8)

print(f"\n📊 ERRORS BY CONFIDENCE LEVEL:")
print(f"{'─'*60}")
print(f"  Low confidence (<50%): {low_conf_errors.sum()} errors")
print(f"  Medium confidence (50-80%): {med_conf_errors.sum()} errors")
print(f"  High confidence (>80%): {high_conf_errors.sum()} errors")

if high_conf_errors.sum() > 0:
    print(f"\n  ⚠️ {high_conf_errors.sum()} high-confidence errors detected!")
    print(f"     These are concerning as the model was very confident but wrong.")

# Create error dataframe
error_df = pd.DataFrame({
    'entity': all_entities[errors_mask],
    'sentence': all_sentences[errors_mask],
    'true_label': [id2label[x] for x in all_true_labels[errors_mask]],
    'pred_label': [id2label[x] for x in all_predictions[errors_mask]],
    'confidence': all_confidences[errors_mask]
})

# Sort by confidence (descending) to see high-confidence errors first
error_df = error_df.sort_values('confidence', ascending=False).reset_index(drop=True)

print(f"\n📝 SAMPLE ERRORS (Top 10 by Confidence):")
print(f"{'─'*80}")

for idx in range(min(10, len(error_df))):
    row = error_df.iloc[idx]
    print(f"\n{idx+1}. Entity: {row['entity']}")
    print(f"   Sentence: {row['sentence'][:80]}{'...' if len(row['sentence']) > 80 else ''}")
    print(f"   True: {row['true_label']} | Predicted: {row['pred_label']} | Confidence: {row['confidence']:.2%}")

# Error patterns by class
print(f"\n📊 ERROR PATTERNS:")
print(f"{'─'*60}")

for true_label in ['negative', 'neutral', 'positive']:
    errors_for_class = error_df[error_df['true_label'] == true_label]
    if len(errors_for_class) > 0:
        print(f"\n{true_label.upper()} misclassified as:")
        pred_counts = errors_for_class['pred_label'].value_counts()
        for pred_label, count in pred_counts.items():
            pct = count / len(errors_for_class) * 100
            print(f"  → {pred_label}: {count} ({pct:.1f}%)")

# Save error analysis to CSV
error_df.to_csv('error_analysis.csv', index=False)
print(f"\n✓ Full error analysis saved to 'error_analysis.csv'")
# Out:
# ================================================================================
# TAHAP 8: ERROR ANALYSIS
# ================================================================================
#
# 📋 ERROR STATISTICS:
# ────────────────────────────────────────────────────────────
#   Total errors: 71 / 2899
#   Error rate: 2.45%
#   Accuracy: 97.55%
#
# 📊 ERRORS BY CONFIDENCE LEVEL:
# ────────────────────────────────────────────────────────────
#   Low confidence (<50%): 0 errors
#   Medium confidence (50-80%): 14 errors
#   High confidence (>80%): 57 errors
#
#   ⚠️ 57 high-confidence errors detected!
#      These are concerning as the model was very confident but wrong.
#
# 📝 SAMPLE ERRORS (Top 10 by Confidence):
# ────────────────────────────────────────────────────────────────────────────────
#
# 1. Entity: PSU banks
#    Sentence: Near-term trajectory of PSU banks shaky, but buy stocks on dips: Parag Thakkar
#    True: positive | Predicted: negative | Confidence: 98.78%
#
# 2. Entity: Mirza International
#    Sentence: Mirza International has been sideways: Deepak Mohoni
#    True: neutral | Predicted: negative | Confidence: 98.57%
#
# 3. Entity: OMCs
#    Sentence: OMCs pullback on hopes of no fuel price cut in near term
#    True: positive | Predicted: negative | Confidence: 98.23%
#
# 4. Entity: Grasim
#    Sentence: VSF halved Grasim fortunes compared to Ultratech
#    True: neutral | Predicted: negative | Confidence: 98.13%
#
# 5. Entity: Diamond
#    Sentence: Diamond sales in domestic market remains flat despite regulatory measures
#    True: negative | Predicted: neutral | Confidence: 97.66%
#
# 6. Entity: Nifty
#    Sentence: Continue to buy till Nifty breaks 8090-8100 levels: Mitesh Thacker
#    True: neutral | Predicted: positive | Confidence: 97.54%
#
# 7. Entity: Ramsarup
#    Sentence: Upside capped at 90 for Ramsarup: Siddth Capital
#    True: neutral | Predicted: positive | Confidence: 96.87%
#
# 8. Entity: food
#    Sentence: Panel to monitor food futures
#    True: negative | Predicted: neutral | Confidence: 96.72%
#
# 9. Entity: HFC
#    Sentence: HFCs offer great value even at prevailing levels; prefer Repco Home: Vinay Khatt...
#    True: neutral | Predicted: positive | Confidence: 96.58%
#
# 10. Entity: SBI
#    Sentence: SBI's Bhushan Steel bail out plan may face hurdles as lenders turn unsupportive
#    True: negative | Predicted: neutral | Confidence: 96.58%
#
# 📊 ERROR PATTERNS:
# ────────────────────────────────────────────────────────────
#
# NEGATIVE misclassified as:
#   → neutral: 12 (80.0%)
#   → positive: 3 (20.0%)
#
# NEUTRAL misclassified as:
#   → positive: 25 (64.1%)
#   → negative: 14 (35.9%)
#
# POSITIVE misclassified as:
#   → neutral: 10 (58.8%)
#   → negative: 7 (41.2%)
#
# ✓ Full error analysis saved to 'error_analysis.csv'

# %% [markdown]
# Confidence Distribution Analysis

# %%
print("\n" + "="*80)
print("CONFIDENCE DISTRIBUTION ANALYSIS")
print("="*80)

fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Plot 1: Overall confidence distribution
axes[0, 0].hist(all_confidences, bins=50, edgecolor='black', alpha=0.7)
axes[0, 0].axvline(np.mean(all_confidences), color='r', linestyle='--', 
                    linewidth=2, label=f'Mean: {np.mean(all_confidences):.3f}')
axes[0, 0].set_title('Overall Confidence Distribution', fontsize=14, fontweight='bold')
axes[0, 0].set_xlabel('Confidence Score')
axes[0, 0].set_ylabel('Frequency')
axes[0, 0].legend()
axes[0, 0].grid(alpha=0.3)

# Plot 2: Confidence by correctness
correct_mask = all_predictions == all_true_labels
correct_conf = all_confidences[correct_mask]
incorrect_conf = all_confidences[~correct_mask]

axes[0, 1].hist([correct_conf, incorrect_conf], bins=30, 
                label=['Correct', 'Incorrect'], 
                alpha=0.7, edgecolor='black')
axes[0, 1].set_title('Confidence Distribution by Correctness', fontsize=14, fontweight='bold')
axes[0, 1].set_xlabel('Confidence Score')
axes[0, 1].set_ylabel('Frequency')
axes[0, 1].legend()
axes[0, 1].grid(alpha=0.3)

# Plot 3: Confidence by true class
for label_id in [0, 1, 2]:
    mask = all_true_labels == label_id
    axes[1, 0].hist(all_confidences[mask], bins=30, alpha=0.5, 
                    label=target_names[label_id], edgecolor='black')
axes[1, 0].set_title('Confidence Distribution by True Class', fontsize=14, fontweight='bold')
axes[1, 0].set_xlabel('Confidence Score')
axes[1, 0].set_ylabel('Frequency')
axes[1, 0].legend()
axes[1, 0].grid(alpha=0.3)

# Plot 4: Accuracy vs Confidence bins
conf_bins = np.linspace(0, 1, 11)
bin_centers = (conf_bins[:-1] + conf_bins[1:]) / 2
bin_accuracies = []
bin_counts = []

for i in range(len(conf_bins) - 1):
    mask = (all_confidences >= conf_bins[i]) & (all_confidences < conf_bins[i+1])
    if mask.sum() > 0:
        bin_acc = (all_predictions[mask] == all_true_labels[mask]).mean()
        bin_accuracies.append(bin_acc)
        bin_counts.append(mask.sum())
    else:
        bin_accuracies.append(0)
        bin_counts.append(0)

axes[1, 1].bar(bin_centers, bin_accuracies, width=0.08, alpha=0.7, edgecolor='black')
axes[1, 1].plot([0, 1], [0, 1], 'r--', linewidth=2, label='Perfect Calibration')
axes[1, 1].set_title('Accuracy vs Confidence (Calibration)', fontsize=14, fontweight='bold')
axes[1, 1].set_xlabel('Confidence Score')
axes[1, 1].set_ylabel('Accuracy')
axes[1, 1].legend()
axes[1, 1].grid(alpha=0.3)
axes[1, 1].set_xlim([0, 1])
axes[1, 1].set_ylim([0, 1])

plt.tight_layout()
plt.show()

print("\n📊 CONFIDENCE STATISTICS:")
print(f"{'─'*60}")
print(f"  Mean confidence: {np.mean(all_confidences):.4f}")
print(f"  Median confidence: {np.median(all_confidences):.4f}")
print(f"  Std confidence: {np.std(all_confidences):.4f}")
print(f"\n  Correct predictions - Mean confidence: {np.mean(correct_conf):.4f}")
print(f"  Incorrect predictions - Mean confidence: {np.mean(incorrect_conf):.4f}")
# Out:
# ================================================================================
# CONFIDENCE DISTRIBUTION ANALYSIS
# ================================================================================
# 📊 CONFIDENCE STATISTICS:
# ────────────────────────────────────────────────────────────
#   Mean confidence: 0.9622
#   Median confidence: 0.9670
#   Std confidence: 0.0408
#
#   Correct predictions - Mean confidence: 0.9645
#   Incorrect predictions - Mean confidence: 0.8713

# %% [markdown]
# Summary

# %%
print("\n" + "="*80)
print("SUMMARY - MODEL EVALUATION COMPLETE")
print("="*80)

print(f"\n✅ FINAL RESULTS:")
print(f"{'─'*60}")
print(f"  Test Accuracy: {test_accuracy*100:.2f}%")
print(f"  Test F1-Score (Macro): {test_f1_macro:.4f}")
print(f"  Total Errors: {num_errors} / {len(all_predictions)}")
print(f"  Mean Confidence: {np.mean(all_confidences)*100:.1f}%")

print(f"\n✅ FILES GENERATED:")
print(f"{'─'*60}")
print(f"  - error_analysis.csv (detailed error breakdown)")
print(f"  - Multiple visualization plots")

print(f"\n✅ NEXT STEPS (Tahap 9 - Dokumentasi):")
print(f"{'─'*60}")
print(f"  1. Screenshot semua hasil visualisasi")
print(f"  2. Compile insights dari error analysis")
print(f"  3. Buat laporan final dengan interpretasi hasil")
print(f"  4. Diskusikan dengan kelompok tentang findings")

print("\n" + "="*80)
# Out:
# ================================================================================
# SUMMARY - MODEL EVALUATION COMPLETE
# ================================================================================
#
# ✅ FINAL RESULTS:
# ────────────────────────────────────────────────────────────
#   Test Accuracy: 97.55%
#   Test F1-Score (Macro): 0.9757
#   Total Errors: 71 / 2899
#   Mean Confidence: 96.2%
#
# ✅ FILES GENERATED:
# ────────────────────────────────────────────────────────────
#   - error_analysis.csv (detailed error breakdown)
#   - Multiple visualization plots
#
# ✅ NEXT STEPS (Tahap 9 - Dokumentasi):
# ────────────────────────────────────────────────────────────
#   1. Screenshot semua hasil visualisasi
#   2. Compile insights dari error analysis
#   3. Buat laporan final dengan interpretasi hasil
#   4. Diskusikan dengan kelompok tentang findings
#
# ================================================================================

# %% [markdown]
# # SAVE MODEL

# %% [markdown]
# Tokenizer Configuration

# %%
# Save tokenizer untuk consistency
from transformers import RobertaTokenizer

tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
tokenizer.save_pretrained('./saved_model/tokenizer')
# Out:
# ('./saved_model/tokenizer\\tokenizer_config.json',
#  './saved_model/tokenizer\\special_tokens_map.json',
#  './saved_model/tokenizer\\vocab.json',
#  './saved_model/tokenizer\\merges.txt',
#  './saved_model/tokenizer\\added_tokens.json')

# %% [markdown]
# Model Metadata/Config

# %%
# Save configuration untuk reproducibility
import json

model_config = {
    'model_name': 'RoBERTa-ABSA-SEntFiN',
    'base_model': 'roberta-base',
    'num_labels': 3,
    'dropout_rate': 0.3,
    'max_length': 40,
    'label2id': {'negative': 0, 'neutral': 1, 'positive': 2},
    'id2label': {0: 'negative', 1: 'neutral', 2: 'positive'},
    'training_config': {
        'learning_rate': 2e-5,
        'batch_size': 128,
        'epochs_trained': 11,
        'best_epoch': 6,
        'best_val_f1': 0.9019
    },
    'test_performance': {
        'accuracy': 0.9755,
        'f1_macro': 0.9757,
        'test_date': '2025-11-13'
    }
}

with open('./saved_model/model_config.json', 'w') as f:
    json.dump(model_config, f, indent=2)

# %% [markdown]
# Label Encodings

# %%
# Save label mappings
import pickle

label_info = {
    'label2id': {'negative': 0, 'neutral': 1, 'positive': 2},
    'id2label': {0: 'negative', 1: 'neutral', 2: 'positive'}
}

with open('./saved_model/label_mappings.pkl', 'wb') as f:
    pickle.dump(label_info, f)
